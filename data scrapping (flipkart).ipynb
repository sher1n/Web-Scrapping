# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url='https://www.flipkart.com/search?q=laptop&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_HistoryAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_HistoryAutoSuggest_1_3_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=laptop%7CLaptops&requestId=7072ca97-66a8-4410-8cff-eb21374d2102'

# %%
allow=requests.get(url)

# %%
allow
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(allow.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
laptop=soup.select('._4rR01T')

# %%
laptop
# Out:
# [<div class="_4rR01T">Lenovo Legion 5 Ryzen 7 Octa Core 5800H - (16 GB/1 TB SSD/Windows 10 Home/6 GB Graphics/NVIDIA GeForce...</div>,
#  <div class="_4rR01T">Lenovo IdeaPad Gaming 3 Core i5 11th Gen - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeFor...</div>,
#  <div class="_4rR01T">MSI Modern 14 Ryzen 5 Hexa Core 4500U - (8 GB/512 GB SSD/Windows 10 Home) Modern 14 B4MW-423IN Thin an...</div>,
#  <div class="_4rR01T">Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15ITL6 Thin and Light Laptop</div>,
#  <div class="_4rR01T">ASUS VivoBook 15 (2021) Core i3 11th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 11 Home) X515EA-EJ332WS T...</div>,
#  <div class="_4rR01T">Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 GB SSD/Windows 11 Home) 15IML05 Thin and Light Laptop</div>,
#  <div class="_4rR01T">HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15s-fq2627TU Thin and Light Laptop</div>,
# ...

# %%
lap=[]

# %%
for i in laptop:
    lap.append(i.text)

# %%
lap
# Out:
# ['Lenovo Legion 5 Ryzen 7 Octa Core 5800H - (16 GB/1 TB SSD/Windows 10 Home/6 GB Graphics/NVIDIA GeForce...',
#  'Lenovo IdeaPad Gaming 3 Core i5 11th Gen - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeFor...',
#  'MSI Modern 14 Ryzen 5 Hexa Core 4500U - (8 GB/512 GB SSD/Windows 10 Home) Modern 14 B4MW-423IN Thin an...',
#  'Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15ITL6 Thin and Light Laptop',
#  'ASUS VivoBook 15 (2021) Core i3 11th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 11 Home) X515EA-EJ332WS T...',
#  'Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 GB SSD/Windows 11 Home) 15IML05 Thin and Light Laptop',
#  'HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15s-fq2627TU Thin and Light Laptop',
#  'Lenovo IdeaPad Gaming 3 Ryzen 7 Octa Core 5800H - (16 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVID...',
#  'ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515JA-EJ362WS Thin and L...',
# ...

# %%
rate=soup.select('._1_WHN1')

# %%
rate
# Out:
# [<div class="_30jeq3 _1_WHN1">₹1,29,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹59,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹39,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹38,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹37,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹34,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹39,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹74,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹35,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹41,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹36,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹33,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹29,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹35,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹34,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹60,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹54,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹47,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹39,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹59,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹54,990</div>,
# ...

# %%
laprate=[]

# %%
for j in rate:
    laprate.append(j.text)

# %%
laprate
# Out:
# ['₹1,29,990',
#  '₹59,990',
#  '₹39,990',
#  '₹38,990',
#  '₹37,990',
#  '₹34,490',
#  '₹39,490',
#  '₹74,990',
#  '₹35,990',
#  '₹41,990',
#  '₹36,990',
#  '₹33,990',
#  '₹29,990',
#  '₹35,990',
#  '₹34,990',
#  '₹60,990',
#  '₹54,990',
#  '₹47,490',
#  '₹39,990',
#  '₹59,990',
#  '₹54,990',
#  '₹33,990',
#  '₹51,490',
#  '₹1,14,990']

# %%
review=soup.select('._1lRcqv ._3LWZlK')

# %%
review
# Out:
# [<div class="_3LWZlK">3.9<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div>,
# ...

# %%
rating=[]

# %%
for r in review:
    rating.append(r.text)

# %%
rating
# Out:
# ['3.9',
#  '4.6',
#  '4.4',
#  '4.6',
#  '4.3',
#  '4.2',
#  '4.3',
#  '4.3',
#  '4.6',
#  '4',
#  '4.3',
#  '4.4',
#  '4.5',
#  '4.5',
#  '4.3',
#  '4.2',
#  '4.4',
#  '4.5',
#  '5',
#  '4.2',
#  '3.9']

# %%
original=soup.select('._27UcVY')

# %%
original
# Out:
# [<div class="_3I9_wc _27UcVY">₹<!-- -->1,81,890</div>,
#  <div class="_3I9_wc _27UcVY">₹<!-- -->93,690</div>,
#  <div class="_3I9_wc _27UcVY">₹<!-- -->61,990</div>,
#  <div class="_3I9_wc _27UcVY">₹<!-- -->64,490</div>,
#  <div class="_3I9_wc _27UcVY">₹<!-- -->54,990</div>,
#  <div class="_3I9_wc _27UcVY">₹<!-- -->57,990</div>,
#  <div class="_3I9_wc _27UcVY">₹<!-- -->51,506</div>,
#  <div class="_3I9_wc _27UcVY">₹<!-- -->1,18,890</div>,
#  <div class="_3I9_wc _27UcVY">₹<!-- -->50,990</div>,
#  <div class="_3I9_wc _27UcVY">₹<!-- -->51,748</div>,
#  <div class="_3I9_wc _27UcVY">₹<!-- -->62,190</div>,
#  <div class="_3I9_wc _27UcVY">₹<!-- -->57,290</div>,
#  <div class="_3I9_wc _27UcVY">₹<!-- -->46,263</div>,
#  <div class="_3I9_wc _27UcVY">₹<!-- -->48,933</div>,
#  <div class="_3I9_wc _27UcVY">₹<!-- -->52,990</div>,
#  <div class="_3I9_wc _27UcVY">₹<!-- -->93,690</div>,
#  <div class="_3I9_wc _27UcVY">₹<!-- -->76,021</div>,
#  <div class="_3I9_wc _27UcVY">₹<!-- -->68,490</div>,
# ...

# %%
orate=[]

# %%
for k in original:
    orate.append(k.text)

# %%
orate
# Out:
# ['₹1,81,890',
#  '₹93,690',
#  '₹61,990',
#  '₹64,490',
#  '₹54,990',
#  '₹57,990',
#  '₹51,506',
#  '₹1,18,890',
#  '₹50,990',
#  '₹51,748',
#  '₹62,190',
#  '₹57,290',
#  '₹46,263',
#  '₹48,933',
#  '₹52,990',
#  '₹93,690',
#  '₹76,021',
#  '₹68,490',
#  '₹54,781',
#  '₹93,690',
#  '₹81,990',
#  '₹46,990',
#  '₹70,171',
#  '₹1,53,490']

# %%
import pandas as pd

# %%
details=pd.DataFrame(lap,columns=['LAPTOP'])

# %%
details
# Out:
#                                                LAPTOP
# 0   Lenovo Legion 5 Ryzen 7 Octa Core 5800H - (16 ...
# 1   Lenovo IdeaPad Gaming 3 Core i5 11th Gen - (8 ...
# 2   MSI Modern 14 Ryzen 5 Hexa Core 4500U - (8 GB/...
# 3   Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...
# 4   ASUS VivoBook 15 (2021) Core i3 11th Gen - (8 ...
# 5   Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 ...
# 6   HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...
# 7   Lenovo IdeaPad Gaming 3 Ryzen 7 Octa Core 5800...
# 8   ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...
# 9   HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...
# 10  Lenovo Core i3 10th Gen - (8 GB/512 GB SSD/Win...
# 11  Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/1 TB...
# 12  DELL Inspiron Athlon Dual Core 3050U - (8 GB/2...
# 13  HP Core i3 11th Gen - (8 GB/256 GB SSD/Windows...
# 14  ASUS Core i3 11th Gen - (8 GB/256 GB SSD/Windo...
# 15  Lenovo Legion 5 Ryzen 5 Hexa Core 4600H - (8 G...
# ...

# %%
details['original price']=orate

# %%
details
# Out:
#                                                LAPTOP original price
# 0   Lenovo Legion 5 Ryzen 7 Octa Core 5800H - (16 ...      ₹1,81,890
# 1   Lenovo IdeaPad Gaming 3 Core i5 11th Gen - (8 ...        ₹93,690
# 2   MSI Modern 14 Ryzen 5 Hexa Core 4500U - (8 GB/...        ₹61,990
# 3   Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...        ₹64,490
# 4   ASUS VivoBook 15 (2021) Core i3 11th Gen - (8 ...        ₹54,990
# 5   Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 ...        ₹57,990
# 6   HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...        ₹51,506
# 7   Lenovo IdeaPad Gaming 3 Ryzen 7 Octa Core 5800...      ₹1,18,890
# 8   ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...        ₹50,990
# 9   HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...        ₹51,748
# 10  Lenovo Core i3 10th Gen - (8 GB/512 GB SSD/Win...        ₹62,190
# 11  Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/1 TB...        ₹57,290
# 12  DELL Inspiron Athlon Dual Core 3050U - (8 GB/2...        ₹46,263
# ...

# %%
details['DISCOUNT RATE']=laprate

# %%
details
# Out:
#                                                LAPTOP original price  \
# 0   Lenovo Legion 5 Ryzen 7 Octa Core 5800H - (16 ...      ₹1,81,890
# 1   Lenovo IdeaPad Gaming 3 Core i5 11th Gen - (8 ...        ₹93,690
# 2   MSI Modern 14 Ryzen 5 Hexa Core 4500U - (8 GB/...        ₹61,990
# 3   Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...        ₹64,490
# 4   ASUS VivoBook 15 (2021) Core i3 11th Gen - (8 ...        ₹54,990
# 5   Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 ...        ₹57,990
# 6   HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...        ₹51,506
# 7   Lenovo IdeaPad Gaming 3 Ryzen 7 Octa Core 5800...      ₹1,18,890
# 8   ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...        ₹50,990
# 9   HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...        ₹51,748
# 10  Lenovo Core i3 10th Gen - (8 GB/512 GB SSD/Win...        ₹62,190
# 11  Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/1 TB...        ₹57,290
# 12  DELL Inspiron Athlon Dual Core 3050U - (8 GB/2...        ₹46,263
# ...
